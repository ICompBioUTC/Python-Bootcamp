# %%
# %matplotlib inline
import pandas as pd
import glob

idf = pd.DataFrame()
for file in glob.glob("*.csv"):
    this_file_dataframe = pd.read_csv(file)
    idf = idf.append(this_file_dataframe, ignore_index=True)
    
idf
idf.plot(figsize=(12,9), kind='line')

# # Here lies Dax trying to separate different species to different lines on the line graph, and failing.

# uniq = idf['species'].unique()
# all_cols = []
# for i in uniq:
#     this_col = pd.Series()
#     for idx, j in enumerate(idf.loc[:,'species']):
#         if j == i:
#             this_col = this_col.append(pd.Series([idf.loc[idx,'sepal_length']]))
#     all_cols.append(this_col)
    
# new_df = pd.DataFrame()
# for idx, n in enumerate(uniq):
#     new_df = new_df.reset_index()
#     new_df[str(n)] = all_cols[idx]
    
# new_df = new_df.reset_index()
# new_df.plot(figsize=(12,9))
